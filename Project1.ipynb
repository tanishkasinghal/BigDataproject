# %%
import pandas as pd

# %%
df=pd.read_csv('jaipur_data.csv')

# %%
df
# Out:
#           id   m_id  client_m_id    hl_id      state district  rural  \
# 0     163321  205.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 1     163313   41.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 2     163297  163.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 3     163289  217.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 4     163281   82.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 5     163273   31.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 6     163265   45.0          NaN      NaN  RAJASTHAN   JAIPUR  Urban
# 7     575923    NaN          NaN  19883.0  RAJASTHAN   JAIPUR  Urban
# 8     575907  617.0        256.0  19667.0  RAJASTHAN   JAIPUR  Rural
# 9     575915  622.0        136.0  19747.0  RAJASTHAN   JAIPUR  Urban
# 10    575891    NaN          NaN  19383.0  RAJASTHAN   JAIPUR  Rural
# 11    575883    NaN          NaN  19325.0  RAJASTHAN   JAIPUR  Rural
# 12    575899  607.0        246.0  19535.0  RAJASTHAN   JAIPUR  Rural
# ...

# %%
df=df[['state','district','deceased_sex','month_of_death','year_of_death','death_symptoms','is_death_associated_with_preg','marital_status','highest_qualification','drinking_water_source','toilet_used']]

# %%
df
# Out:
#           state district deceased_sex  month_of_death  year_of_death  \
# 0     RAJASTHAN   JAIPUR       Female              10           2011
# 1     RAJASTHAN   JAIPUR         Male               6           2011
# 2     RAJASTHAN   JAIPUR         Male              11           2011
# 3     RAJASTHAN   JAIPUR       Female               3           2011
# 4     RAJASTHAN   JAIPUR       Female               8           2011
# 5     RAJASTHAN   JAIPUR         Male              12           2011
# 6     RAJASTHAN   JAIPUR       Female              11           2011
# 7     RAJASTHAN   JAIPUR       Female              11           2009
# 8     RAJASTHAN   JAIPUR       Female               3           2009
# 9     RAJASTHAN   JAIPUR       Female               8           2007
# 10    RAJASTHAN   JAIPUR       Female              10           2007
# 11    RAJASTHAN   JAIPUR       Female               1           2007
# 12    RAJASTHAN   JAIPUR         Male               8           2009
# ...

# %%
df.to_csv('Filtered_data.csv')
